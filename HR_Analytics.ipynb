# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('people.csv')

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df.head()
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
df.tail()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# 14994                  4             0     1                      0
# 14995                  2             0     0                      0
# 14996                  4             0     0                      0
# 14997                  5             0     0                      0
# 14998                  3             0     0                      0
#
#             dept  salary
# 14994    support  medium
# 14995      sales     low
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.dtypes
# Out:
# satisfactoryLevel        float64
# lastEvaluation           float64
# numberOfProjects           int64
# avgMonthlyHours            int64
# timeSpent.company          int64
# workAccident               int64
# left                       int64
# promotionInLast5years      int64
# dept                      object
# salary                    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3008

# %%
df.drop_duplicates(inplace=True) # dropping duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['left'].value_counts() # to see the count of values in a column
# Out:
# left
# 0    10000
# 1     1991
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %% [markdown]
# ## Inference From The Data

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='numberOfProjects',hue='left',palette=['m','g'])
plt.xlabel('Number Of Projects')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Inference**
#
# The people with project count with 2, 6 and 7 are leaving most.
#
# **Suggestion**
#
# All the employees should be assigned 3-5 projects on average.
#
# It should be redistributed among employees who are working on two projects from 6 and 7

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='promotionInLast5years',hue='left')
plt.xlabel('Promotions In Last 5 Years')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Inference**
#
# People who are not getting the promotion for the last 5 years are leaving the most.
#
# **Suggestion**
#
# Timely promotion for the employees

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='salary',hue='left')
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Inference**
#
# People with low and medium salary are leaving the most.
#
# **Suggestion**
#
# Give salary Hike/incentives/Bonus according to experience and work

# %%
df['salary'].value_counts().plot.pie(autopct='%0.2f%%')
plt.title('Salary Count')
# Out:
# Text(0.5, 1.0, 'Salary Count')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='workAccident',hue='left',palette='plasma')
plt.xlabel('Work Accident')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Inference**
#
# Work accidents are not relevant reason for leaving the company

# %%
plt.figure(figsize=(12,5))
sns.countplot(data=df,x='dept',hue='left',palette='Set1')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Inference**
#
# People of Sales, Technical and Support department are leaving the most.
#
# **Suggestion**
#
# For sales people based on their targets give some incentives.
#
# Give option to move to other departments.
#
# Team Management
#
# Taking outings, lunch, fun activities to reduce the stress level.

# %%
plt.figure(figsize=(12,5))
sns.histplot(data=df,x='avgMonthlyHours',hue='left',element='step',palette='Set2')
plt.xlabel('avgMonthlyHours')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Inference**
#
# People with minimum working hours or maximum monthly hours leave the most.
# That is there is either no work or a lot of work.
#
# **Suggestion**
#
# Distribute work from high working hour employees to ow working hour employees.

# %%
plt.figure(figsize=(12,5))
sns.histplot(data=df,x='satisfactoryLevel',hue='left',element='step',palette='Set2')
plt.xlabel('satisfactoryLevel')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Inference**
#
# People with satisfactory level less than 0.5 are leaving the most
#
# **Suggestion**
#
# It can be due to work culture,salary,working hours, anything. Do personal review for people below satisfactory level 0.5

# %%
plt.figure(figsize=(12,5))
sns.barplot(data=df, y='satisfactoryLevel',x='dept',hue='left',errorbar=None)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df['dept_salary'] = df['dept'] + ' - ' + df['salary']
plt.figure(figsize=(12,5))
sns.countplot(data=df,x='dept_salary',hue='left',palette='Set1')
plt.xticks(rotation=90)
plt.show()

# %%
salary=df.groupby(['dept','salary']).size().unstack().fillna(0)

# %%
salary.plot(kind='bar',stacked=True,figsize=(10,5),colormap='viridis')
# Out:
# <Axes: xlabel='dept'>

# %%
grouped=df.groupby(['dept','salary'])

# %%
grouped=grouped.size()

# %%
grouped
# Out:
# dept         salary
# IT           high        71
#              low        476
#              medium     429
# RandD        high        47
#              low        322
#              medium     325
# accounting   high        63
#              low        296
#              medium     262
# hr           high        38
#              low        296
#              medium     267
# management   high       128
#              low        139
#              medium     169
# marketing    high        62
#              low        310
#              medium     301
# product_mng  high        52
#              low        343
#              medium     291
# sales        high       237
#              low       1553
#              medium    1449
# support      high       126
#              low        867
#              medium     828
# technical    high       166
#              low       1138
#              medium     940
# dtype: int64

# %%
unstacked=grouped.unstack()

# %%
unstacked
# Out:
# salary       high   low  medium
# dept
# IT             71   476     429
# RandD          47   322     325
# accounting     63   296     262
# hr             38   296     267
# management    128   139     169
# marketing      62   310     301
# product_mng    52   343     291
# sales         237  1553    1449
# support       126   867     828
# technical     166  1138     940

# %%
sal_dept_left=df.groupby(['left','dept','salary']).size().unstack(level=[1,2]).fillna(0)

# %%
sal_dept_left.plot(kind='bar',stacked=True,figsize=(12,6),colormap='viridis')
# Out:
# <Axes: xlabel='left'>

# %%
corr=df.corr(numeric_only=True)

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr,annot=True,cmap='magma')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,6))
plt.scatter(df['avgMonthlyHours'],df['timeSpent.company'],c=df['left'],alpha=0.7,edgecolors='w',s=100)
plt.xlabel('Avg Monthly hours')
plt.ylabel('Time spent in company')
plt.colorbar(label='Left status')
plt.show()

# %% [markdown]
# **Inference**
#
# People with less than 5 years at company but working more than 200 hours on avg monthly are leaving the most
#
# **Suggestion**
#
# It can be due to work culture,salary,working hours, anything. Do personal review for people.

# %%
total_employees=df.groupby('dept').size()

# %%
left_employee=df[df['left']==1].groupby('dept').size()

# %%
attrition_rate=(left_employee/total_employees)*100

# %%
attrition_df=pd.DataFrame({'Total Employees':total_employees,'Left Employees':left_employee,'Attrition rate':attrition_rate}).fillna(0)

# %%
attrition_df
# Out:
#              Total Employees  Left Employees  Attrition rate
# dept
# IT                       976             158       16.188525
# RandD                    694              85       12.247839
# accounting               621             109       17.552335
# hr                       601             113       18.801997
# management               436              52       11.926606
# marketing                673             112       16.641902
# product_mng              686             110       16.034985
# sales                   3239             550       16.980550
# support                 1821             312       17.133443
# technical               2244             390       17.379679

# %%
plt.figure(figsize=(10,6))
attrition_df['Attrition rate'].plot(kind='bar',color='skyblue')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(
        attrition_df['Attrition rate'],
        labels=attrition_df.index,autopct='%1.1f%%',colors=plt.cm.plasma(attrition_df['Attrition rate']/max(attrition_df['Attrition rate'])),
        startangle=140,wedgeprops={'edgecolor':'black'}
        )
plt.title("Attrition Rate percentage of each department compared by whole atrrition rate of the company")
plt.show()
